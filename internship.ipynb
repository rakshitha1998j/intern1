# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pylab import *

# %%
data=pd.read_csv(r"C:\Users\Tek\Desktop\data.csv")

# %%
data.head(10)
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9 ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33 ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244 ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85 ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87 ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21 ...     4     2
# 5   X14.V1.56   55   28   18   16   16   19   25   40   52 ...   -12   -31
# 6   X3.V1.191  -55   -9   52  111  135  129  103   72   37 ...  -125   -99
# 7  X11.V1.273    1   -2   -8  -11  -12  -17  -15  -16  -18 ...   -79   -91
# 8  X19.V1.874 -278 -246 -215 -191 -177 -167 -157 -139 -118 ...  -400  -379
# 9   X3.V1.491    8   15   13    3   -6   -8   -5    4   25 ...    49    31
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed: 0 to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
feature=data.drop("Unnamed: 0",axis=1)

# %%
feature.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10 ...  X170  X171  X172  \
# 0  135  190  229  223  192  125   55   -9  -33  -38 ...   -17   -15   -31
# 1  386  382  356  331  320  315  307  272  244  232 ...   164   150   146
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94 ...    57    64    48
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79 ...   -82   -81   -80
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59 ...     4     2   -12
#
#    X173  X174  X175  X176  X177  X178  y
# 0   -77  -103  -127  -116   -83   -51  4
# 1   152   157   156   154   143   129  1
# 2    19   -12   -30   -35   -35   -36  5
# 3   -77   -85   -77   -72   -69   -65  5
# 4   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 179 columns]

# %%
features=feature.drop("y",axis=1)

# %%
features.head()
# Out:
#     X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...   X169  X170  X171  \
# 0  135  190  229  223  192  125   55   -9  -33  -38  ...      8   -17   -15
# 1  386  382  356  331  320  315  307  272  244  232  ...    168   164   150
# 2  -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...     29    57    64
# 3 -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...    -80   -82   -81
# 4   -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     10     4     2
#
#    X172  X173  X174  X175  X176  X177  X178
# 0   -31   -77  -103  -127  -116   -83   -51
# 1   146   152   157   156   154   143   129
# 2    48    19   -12   -30   -35   -35   -36
# 3   -80   -77   -85   -77   -72   -69   -65
# 4   -12   -32   -41   -65   -83   -89   -73
#
# [5 rows x 178 columns]

# %%
label1=features.iloc[1]
label1.plot(kind='line')
plt.show()

# %%
label2=features.iloc[7]
label2.plot(kind='line')
plt.show()

# %%
label3=features.iloc[12]
label3.plot(kind='line')
plt.show()

# %%
label4=features.iloc[0]
label4.plot(kind='line')
plt.show()

# %%
label5=features.iloc[2]
label5.plot(kind='line')
plt.show()

# %%
a=features.head(100)
a
# Out:
#      X1   X2   X3   X4   X5   X6   X7   X8   X9  X10  ...   X169  X170  X171  \
# 0   135  190  229  223  192  125   55   -9  -33  -38  ...      8   -17   -15
# 1   386  382  356  331  320  315  307  272  244  232  ...    168   164   150
# 2   -32  -39  -47  -37  -32  -36  -57  -73  -85  -94  ...     29    57    64
# 3  -105 -101  -96  -92  -89  -95 -102 -100  -87  -79  ...    -80   -82   -81
# 4    -9  -65  -98 -102  -78  -48  -16    0  -21  -59  ...     10     4     2
# 5    55   28   18   16   16   19   25   40   52   66  ...     -6   -12   -31
# 6   -55   -9   52  111  135  129  103   72   37    0  ...   -137  -125   -99
# 7     1   -2   -8  -11  -12  -17  -15  -16  -18  -17  ...    -67   -79   -91
# 8  -278 -246 -215 -191 -177 -167 -157 -139 -118  -92  ...   -386  -400  -379
# 9     8   15   13    3   -6   -8   -5    4   25   41  ...     65    49    31
# 10   -5   15   28   28    9  -29  -41  -19   14   30  ...    -51   -38    -4
# ...

# %%
b=features.iloc[101:201]
b
# Out:
#       X1   X2   X3   X4   X5    X6    X7   X8   X9  X10  ...   X169  X170  \
# 101   31    8   -9  -29  -34   -28   -12    8   29   48  ...     12    48
# 102  -31   19   49   56   55    40    15   23   35   15  ...    -20   -16
# 103   45   41   30   17   10    -1    -2   -5   -2   -3  ...   -159  -148
# 104   19   15   11   -2  -15   -24   -25   -8   11   14  ...     41    53
# 105 -125 -130 -129 -134 -139  -149  -150 -156 -158 -162  ...   -291  -279
# 106  -80  -77  -68  -69  -70   -67   -69  -66  -67  -66  ...    -85   -89
# 107  -27  -25  -25  -27  -37   -50   -61  -72  -79  -81  ...    -85  -102
# 108  -57  -63  -55  -57  -43   -24    -5   13   21   24  ...    -60   -63
# 109   68   75   86   91   93    94    90   91   84   80  ...     45    43
# 110  -37  -21  -11  -13    0     2     2   11    8   -4  ...    101    94
# 111  -63  -63  -85 -102 -104  -104  -117 -112  -98  -90  ...    -76   -76
# 112  -49  -49  -46  -39  -37   -31   -23  -17  -14  -11  ...    -22   -26
# ...

# %%
feature1=data.sort_values(by="y")
feature1
# Out:
#        Unnamed: 0    X1    X2    X3    X4    X5   X6    X7    X8    X9 ...  \
# 10145   X7.V1.117  -362  -327  -229   -56   148  318   416   514   630 ...
# 6388   X20.V1.924 -1839 -1838 -1835 -1687 -1186 -836  -698  -656  -727 ...
# 6384   X18.V1.316   -62    -4    30    40    36   34    43    52    56 ...
# 6383   X18.V1.534    48    34    51    99   188  306   419   496   522 ...
# 10054  X19.V1.704  -181  -180  -170  -155  -143 -136  -131  -116  -104 ...
# 6382    X4.V1.717  -230  -268  -243  -130    59  209   255   194   133 ...
# 2816   X22.V1.374  -108  -100   -94   -85   -83  -71   -69   -62   -62 ...
# 8253    X7.V1.194   377   457   411   290   162   96    40   -39  -165 ...
# 2821    X7.V1.974   542   501   380   196     8 -169  -346  -458  -565 ...
# 2822   X13.V1.634  -106   -44    17    76   131  178   212   232   233 ...
# 8247   X14.V1.694  -254  -305  -344  -305  -191  -24   133   245   288 ...
# ...

# %%
a=feature.iloc[:,-1]
a
# Out:
# 0        4
# 1        1
# 2        5
# 3        5
# 4        5
# 5        5
# 6        4
# 7        2
# 8        1
# 9        4
# 10       5
# 11       1
# 12       3
# 13       4
# 14       2
# 15       3
# 16       2
# 17       3
# 18       4
# 19       2
# 20       1
# 21       2
# 22       1
# 23       1
# 24       1
# 25       3
# 26       5
# 27       1
# 28       2
# 29       2
#         ..
# 11470    3
# 11471    1
# 11472    3
# 11473    2
# 11474    5
# 11475    3
# 11476    1
# 11477    4
# 11478    1
# 11479    2
# 11480    5
# 11481    1
# 11482    1
# 11483    3
# 11484    2
# 11485    5
# 11486    4
# 11487    1
# 11488    1
# 11489    5
# 11490    1
# 11491    2
# 11492    1
# 11493    2
# 11494    3
# 11495    2
# 11496    1
# 11497    5
# 11498    3
# 11499    4
# Name: y, Length: 11500, dtype: int64

# %%
count=0
count1=0
count2=0
count3=0
count4=0
for k in range(11500):
        if a[k]==1:
            count+=1
        elif a[k]==2:
            count1+=1
        elif a[k]==3:
            count2+=1      
        elif a[k]==4:
            count3+=1
        elif a[k]==5:
            count4+=1
                    
print(count)
print(count1)
print(count2)
print(count3)
print(count4)
# Out:
# 2300
# 2300
# 2300
# 2300
# 2300

# %%
b=np.array(feature.iloc[:,-1])
b
count=0
count1=0
count2=0
count3=0
count4=0
for k in range(11500):
        if b[k]==1:
            count+=1
        elif b[k]==2:
            count1+=1
        elif b[k]==3:
            count2+=1      
        elif b[k]==4:
            count3+=1
        elif b[k]==5:
            count4+=1
print(b)                    
print(count)
print(count1)
print(count2)
print(count3)
print(count4)
# Out:
# [4 1 5 ... 5 3 4]
# 2300
# 2300
# 2300
# 2300
# 2300

# %%
df=np.array(feature.iloc[0:101])
df
# Out:
# array([[135, 190, 229, ..., -83, -51,   4],
#        [386, 382, 356, ..., 143, 129,   1],
#        [-32, -39, -47, ..., -35, -36,   5],
#        ...,
#        [ 54,  43,  30, ...,  43,  19,   5],
#        [ 46,  54,  33, ..., -23, -36,   4],
#        [705, 581, 397, ..., 330, 326,   1]], dtype=int64)

# %%
df.max()
# Out:
# 1375

# %%
df.min()
# Out:
# -1716

# %%
bin=np.linspace(-1716,1375,5)
bin
# Out:
# array([-1716.  ,  -943.25,  -170.5 ,   602.25,  1375.  ])

# %%
d=array([1,2,3,4,6,7,8])
d
# Out:
# array([1, 2, 3, 4, 6, 7, 8])

# %%
e=linspace(1,3,5)
e
# Out:
# array([1. , 1.5, 2. , 2.5, 3. ])

# %%
feature1.index
# Out:
# Int64Index([10145,  6388,  6384,  6383, 10054,  6382,  2816,  8253,  2821,
#              2822,
#             ...
#              4400,  4396,  4395,  4394,  4389,  4387,  4385,  4384,  4451,
#              5749],
#            dtype='int64', length=11500)

# %%
k=feature1.groupby(["y"]).mean()
k
# Out:
#           X1         X2         X3         X4         X5         X6  \
# y
# 1 -21.936522 -19.049130 -15.293913  -9.836087  -3.707391   2.730000
# 2  -7.710000  -8.148696  -8.020000  -8.050435  -7.776957  -8.220870
# 3  -9.207391  -9.276522  -9.968261 -10.634348 -11.172174 -11.559130
# 4 -12.726087 -12.410435 -12.272609 -12.096957 -12.083043 -12.349130
# 5  -6.326957  -5.673043  -5.380870  -5.097391  -5.309130  -5.618261
#
#           X7         X8         X9        X10    ...           X169  \
# y                                                ...
# 1   6.899565   7.425652   8.380870  10.773913    ...      -7.266522
# 2  -8.597826  -9.210000  -9.217826  -9.347826    ...      -7.979565
# 3 -11.797826 -12.013043 -12.132609 -12.249130    ...     -13.590000
# 4 -13.064348 -13.419565 -13.441739 -13.147826    ...     -13.428696
# 5  -5.950000  -6.218696  -6.378696  -6.871304    ...      -5.229565
#
#         X170       X171       X172       X173       X174       X175  \
# y
# ...

# %%
class1=k.iloc[0]
class1.plot(kind='line')
plt.show()

# %%
class2=k.iloc[1]
class2.plot(kind='line')
plt.show()

# %%
class3=k.iloc[2]
class3.plot(kind='line')
plt.show()

# %%
class4=k.iloc[3]
class4.plot(kind='line')
plt.show()

# %%
class5=k.iloc[4]
class5.plot(kind='line')
plt.show()

# %%
class1.min()
# Out:
# -26.42478260869565

# %%
class1.max()
# Out:
# 12.320869565217391

# %%
class2.min()
# Out:
# -10.52304347826087

# %%
class2.max()
# Out:
# -1.1308695652173912

# %%
class3.min()
# Out:
# -13.59

# %%
class3.max()
# Out:
# -4.681739130434782

# %%
class4.min()
# Out:
# -14.524347826086956

# %%
class4.max()
# Out:
# -9.961304347826086

# %%
class5.min()
# Out:
# -7.770869565217391

# %%
class5.max()
# Out:
# -4.83
